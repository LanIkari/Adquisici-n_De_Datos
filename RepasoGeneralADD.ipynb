# %% [markdown]
# <a href="https://colab.research.google.com/github/LanIkari/Adquisicion_De_Datos/blob/main/RepasoGeneralADD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import random 
from datetime import datetime,timedelta, date

# %%
df = pd.read_json('https://raw.githubusercontent.com/omarmendoza564/datos/main/datos/alumnos_calif_jsonArray.json')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 808 entries, 0 to 807
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   clave_alu     808 non-null    int64
#  1   ap_paterno    808 non-null    object
#  2   ap_materno    808 non-null    object
#  3   nombre        808 non-null    object
#  4   sexo          682 non-null    object
#  5   ciudad        698 non-null    object
#  6   email         634 non-null    object
#  7   calificacion  805 non-null    float64
#  8   curp          576 non-null    object
# dtypes: float64(1), int64(1), object(7)
# memory usage: 56.9+ KB

# %%
df
# Out:
#      clave_alu ap_paterno ap_materno         nombre sexo  \
# 0     11030172   BORBOLLA      RAMOS        ARGELIA    F
# 1     11030173     CASTRO    MANCERA  KARLA MARIANA    F
# 2     11030177   FERRUSCA    ANDRADE        OCTAVIO    M
# 3     11030178     GARCIA      GOMEZ         RAFAEL    M
# 4     11030180  GUTIERREZ     FLORES   CARLOS DAVID    M
# ..         ...        ...        ...            ...  ...
# 803   12080001                                       NaN
# 804   14080001      MEJIA    JIMENEZ          LUISA  NaN
# 805   14080002      MEJIA    JIMENEZ          LUISA  NaN
# 806   14080003      MEJIA    JIMENEZ          LUISA  NaN
# 807   14080004      MEJIA    JIMENEZ          LUISA  NaN
#
#                     ciudad                        email  calificacion  \
# 0                QUERETARO         argi_gogos@email.com           5.0
# 1    SANTIAGO DE QUERETARO                          NaN           5.0
# ...

# %%
df.isnull()
# Out:
#      clave_alu  ap_paterno  ap_materno  nombre   sexo  ciudad  email  \
# 0        False       False       False   False  False   False  False
# 1        False       False       False   False  False   False   True
# 2        False       False       False   False  False   False  False
# 3        False       False       False   False  False   False  False
# 4        False       False       False   False  False   False  False
# ..         ...         ...         ...     ...    ...     ...    ...
# 803      False       False       False   False   True    True   True
# 804      False       False       False   False   True    True   True
# 805      False       False       False   False   True    True   True
# 806      False       False       False   False   True    True   True
# 807      False       False       False   False   True    True   True
#
#      calificacion   curp
# 0           False   True
# 1           False   True
# 2           False   True
# 3           False  False
# ...

# %%
df.isnull().sum()
# Out:
# clave_alu         0
# ap_paterno        0
# ap_materno        0
# nombre            0
# sexo            126
# ciudad          110
# email           174
# calificacion      3
# curp            232
# dtype: int64

# %%
df[df['nombre']==''].count()
# Out:
# clave_alu       1
# ap_paterno      1
# ap_materno      1
# nombre          1
# sexo            0
# ciudad          0
# email           0
# calificacion    1
# curp            0
# dtype: int64

# %%
df[1:5]['ap_materno']
# Out:
# 1    MANCERA
# 2    ANDRADE
# 3      GOMEZ
# 4     FLORES
# Name: ap_materno, dtype: object

# %%
df[1:5][['ap_paterno','ap_materno','nombre']]
# Out:
#   ap_paterno ap_materno         nombre
# 1     CASTRO    MANCERA  KARLA MARIANA
# 2   FERRUSCA    ANDRADE        OCTAVIO
# 3     GARCIA      GOMEZ         RAFAEL
# 4  GUTIERREZ     FLORES   CARLOS DAVID

# %%
df[pd.isnull(df['curp'])]
# Out:
#      clave_alu ap_paterno ap_materno         nombre sexo  \
# 0     11030172   BORBOLLA      RAMOS        ARGELIA    F
# 1     11030173     CASTRO    MANCERA  KARLA MARIANA    F
# 2     11030177   FERRUSCA    ANDRADE        OCTAVIO    M
# 7     11030199    ROSALES     APREZA  NESTOR MARTIN    M
# 9     11030204    VAZQUEZ   GONZALEZ        ROBERTO    M
# ..         ...        ...        ...            ...  ...
# 803   12080001                                       NaN
# 804   14080001      MEJIA    JIMENEZ          LUISA  NaN
# 805   14080002      MEJIA    JIMENEZ          LUISA  NaN
# 806   14080003      MEJIA    JIMENEZ          LUISA  NaN
# 807   14080004      MEJIA    JIMENEZ          LUISA  NaN
#
#                     ciudad                    email  calificacion curp
# 0                QUERETARO     argi_gogos@email.com           5.0  NaN
# 1    SANTIAGO DE QUERETARO                      NaN           5.0  NaN
# ...

# %%
df[pd.isnull(df['curp']) & pd.isnull(df['ciudad'])]
# Out:
#      clave_alu  ap_paterno            ap_materno         nombre sexo ciudad  \
# 19    11030232       PEREZ  DEL CASTILLO VELASCO        ESTEBAN  NaN    NaN
# 22    11030242     ALCOCER               ESCOBAR        AGUSTIN    M    NaN
# 33    11030292       PEREA               PACHECO       FERNANDO  NaN    NaN
# 40    11040010  DEL CORRAL              GUERRERO        ABRAHAM    F    NaN
# 54    11040043     VAZQUEZ               ARTEAGA  THALIA IVETTE    F    NaN
# ..         ...         ...                   ...            ...  ...    ...
# 803   12080001                                                   NaN    NaN
# 804   14080001       MEJIA               JIMENEZ          LUISA  NaN    NaN
# 805   14080002       MEJIA               JIMENEZ          LUISA  NaN    NaN
# 806   14080003       MEJIA               JIMENEZ          LUISA  NaN    NaN
# 807   14080004       MEJIA               JIMENEZ          LUISA  NaN    NaN
#
#                           email  calificacion curp
# ...

# %%
df_na_calif=df[pd.isnull(df['calificacion'])]['calificacion'].isna()
#df_na_calif.describe()
df_na_calif
# Out:
# 567    True
# 568    True
# 605    True
# Name: calificacion, dtype: bool

# %%
df['calificacion'].describe()
# Out:
# count    805.000000
# mean       6.065291
# std        1.585511
# min        5.000000
# 25%        5.000000
# 50%        5.000000
# 75%        7.461500
# max       10.000000
# Name: calificacion, dtype: float64

# %%
df[df.index.isin(df_na_calif.index)]
# Out:
#      clave_alu  ap_paterno ap_materno       nombre sexo     ciudad  \
# 567   11070290  PLASCENCIA     MADRID  MAXIMILIANO    M  QUERETARO
# 568   11070302     PALOMAR      TREJO     VERONICA  NaN  QUERETARO
# 605   11080011     BARRERA   CURTIDOR         HUGO    M  QUERETARO
#
#                         email  calificacion curp
# 567  maxplascenciam@email.com           NaN  NaN
# 568  va_la_cachimba@email.com           NaN  NaN
# 605           mbt67mx@aol.com           NaN  NaN

# %%
df_na_calif.index
# Out:
# Int64Index([567, 568, 605], dtype='int64')

# %%
df.columns
# Out:
# Index(['clave_alu', 'ap_paterno', 'ap_materno', 'nombre', 'sexo', 'ciudad',
#        'email', 'calificacion', 'curp'],
#       dtype='object')

# %%
df['calificacion'].fillna(value=df['calificacion'].min(),inplace=True)
df[df.index.isin(df_na_calif.index)]
# Out:
#      clave_alu  ap_paterno ap_materno       nombre sexo     ciudad  \
# 567   11070290  PLASCENCIA     MADRID  MAXIMILIANO    M  QUERETARO
# 568   11070302     PALOMAR      TREJO     VERONICA  NaN  QUERETARO
# 605   11080011     BARRERA   CURTIDOR         HUGO    M  QUERETARO
#
#                         email  calificacion curp
# 567  maxplascenciam@email.com           5.0  NaN
# 568  va_la_cachimba@email.com           5.0  NaN
# 605           mbt67mx@aol.com           5.0  NaN

# %%
print('Promedio ', df['calificacion'].mean())
print('Max ', df['calificacion'].max())
print('Min ', df['calificacion'].min())
print('No Calificaciones ', df['calificacion'].count())
print('Sum tolal ', df['calificacion'].sum())
# Out:
# Promedio  6.061335272277228
# Max  10.0
# Min  5.0
# No Calificaciones  808
# Sum tolal  4897.5589

# %%
df.isnull().sum()
# Out:
# clave_alu         0
# ap_paterno        0
# ap_materno        0
# nombre            0
# sexo            126
# ciudad          110
# email           174
# calificacion      0
# curp            232
# dtype: int64

# %%
df['gpa']=(((df['calificacion']*100) / df['calificacion'].max()) / 20) -1
df.sort_values(by='calificacion', ascending=False)
# Out:
#      clave_alu ap_paterno ap_materno             nombre sexo  \
# 807   14080004      MEJIA    JIMENEZ              LUISA  NaN
# 579   11070375      CONDE     MORENO     BRENDA CELESTE    F
# 553   11070167         PI       VEGA            ROGELIO    M
# 528   11070041      AYALA    CABRERA  ESTEFANIA DELIDIA    F
# 390   11060066   GUERRERO       DIAZ       PERLA SELENE    F
# ..         ...        ...        ...                ...  ...
# 99    11040164    MONTIEL     ZAMORA       MARTHA PAOLA    F
# 100   11040165     OLVERA     RANGEL      JORGE ALBERTO    M
# 434   11060123   PANIAGUA   GONZALEZ     MARIA FERNANDA    F
# 101   11040167    REYNOSO    SANCHEZ          LUIS RENE  NaN
# 0     11030172   BORBOLLA      RAMOS            ARGELIA    F
#
#                     ciudad                    email  calificacion  \
# 807                    NaN                      NaN       10.0000
# 579              QUERETARO      pam.eliz@himail.com        9.7273
# ...

# %%
df[df['calificacion'] > 5].sort_values(by=['sexo', 'calificacion'], ascending=[True, False])
# Out:
#      clave_alu ap_paterno ap_materno             nombre sexo  \
# 579   11070375      CONDE     MORENO     BRENDA CELESTE    F
# 390   11060066   GUERRERO       DIAZ       PERLA SELENE    F
# 528   11070041      AYALA    CABRERA  ESTEFANIA DELIDIA    F
# 426   11060112    NAVARRO     GARCIA   CAMILA ESTEFANIA    F
# 278   11050231    DEL RIO      LICEA           ITZAYANA    F
# ..         ...        ...        ...                ...  ...
# 334   11050333       LUNA     MORENO  ARIADNA YETLANEZI  NaN
# 532   11070055      GRANT      PEREZ     MELANIE CLAIRE  NaN
# 404   11060080      JAIME    VENTURA       JUAN GERARDO  NaN
# 354   11060018   BARRAGAN      BAEZA      ASHLEY MIGUEL  NaN
# 595   11070436    BRIONES       DIAZ    ANTONIO OCTAVIO  NaN
#
#                     ciudad                       email  calificacion  \
# 579              QUERETARO         pam.eliz@himail.com        9.7273
# 390  SANTIAGO DE QUERETARO        pe_fanca94@email.com        9.6364
# ...

# %%
df.drop(['curp'], axis =1, inplace=True)
df
# Out:
#      clave_alu ap_paterno ap_materno         nombre sexo  \
# 0     11030172   BORBOLLA      RAMOS        ARGELIA    F
# 1     11030173     CASTRO    MANCERA  KARLA MARIANA    F
# 2     11030177   FERRUSCA    ANDRADE        OCTAVIO    M
# 3     11030178     GARCIA      GOMEZ         RAFAEL    M
# 4     11030180  GUTIERREZ     FLORES   CARLOS DAVID    M
# ..         ...        ...        ...            ...  ...
# 803   12080001                                       NaN
# 804   14080001      MEJIA    JIMENEZ          LUISA  NaN
# 805   14080002      MEJIA    JIMENEZ          LUISA  NaN
# 806   14080003      MEJIA    JIMENEZ          LUISA  NaN
# 807   14080004      MEJIA    JIMENEZ          LUISA  NaN
#
#                     ciudad                        email  calificacion  gpa
# 0                QUERETARO         argi_gogos@email.com           5.0  1.5
# 1    SANTIAGO DE QUERETARO                          NaN           5.0  1.5
# ...

# %%
sti=pd.date_range("2018-01-01", periods=df.clave_alu.count(), freq='1d')
print (df.clave_alu.count())
print(sti)
df['fecha']=sti
# Out:
# 808
# DatetimeIndex(['2018-01-01', '2018-01-02', '2018-01-03', '2018-01-04',
#                '2018-01-05', '2018-01-06', '2018-01-07', '2018-01-08',
#                '2018-01-09', '2018-01-10',
#                ...
#                '2020-03-09', '2020-03-10', '2020-03-11', '2020-03-12',
#                '2020-03-13', '2020-03-14', '2020-03-15', '2020-03-16',
#                '2020-03-17', '2020-03-18'],
#               dtype='datetime64[ns]', length=808, freq='D')

# %%
print ("Fecha maxima", df['fecha'].max())
print('Fecha min', df['fecha'].min())
# Out:
# Fecha maxima 2020-03-18 00:00:00
# Fecha min 2018-01-01 00:00:00

# %%
df[df['fecha'] >= datetime (year=2020, month=3, day =1)].sort_values(by ='fecha', ascending=False)
# Out:
#      clave_alu  ap_paterno ap_materno           nombre sexo  \
# 807   14080004       MEJIA    JIMENEZ            LUISA  NaN
# 806   14080003       MEJIA    JIMENEZ            LUISA  NaN
# 805   14080002       MEJIA    JIMENEZ            LUISA  NaN
# 804   14080001       MEJIA    JIMENEZ            LUISA  NaN
# 803   12080001                                          NaN
# 802  120800002     Mendoza          G             Omar  NaN
# 801   11080210    GUERRERO  COLOMBRES      ALDO ENRICO    M
# 800   11080209     MORALES    CARMONA    KARLA MARIANA    F
# 799   11080208    BECERRIL     HUERTA          MARIANA    F
# 798   11080207       LOPEZ    AGUILAR           DANIEL    M
# 797   11080206        NAVA     TORRES   LEONARDO JESUS    M
# 796   11080205       BADUY     VALDEZ    KENNIA ASENET    F
# 795   11080204    AGUILLON   RESENDIZ             JOSE    M
# 794   11080203  VILLAGRANA   BARRAGAN      CARLOS IVAN    M
# 793   11080202      VALLES      RAMOS          MARIANA    F
# ...

# %%
df_dup=df.duplicated(subset=['ap_paterno','ap_materno','nombre', 'email'], keep='last')

# %%
df[df_dup]
# Out:
#      clave_alu ap_paterno ap_materno nombre sexo ciudad email  calificacion  \
# 804   14080001      MEJIA    JIMENEZ  LUISA  NaN    NaN   NaN           5.0
# 805   14080002      MEJIA    JIMENEZ  LUISA  NaN    NaN   NaN           5.0
# 806   14080003      MEJIA    JIMENEZ  LUISA  NaN    NaN   NaN           5.0
#
#      gpa      fecha
# 804  1.5 2020-03-15
# 805  1.5 2020-03-16
# 806  1.5 2020-03-17

# %%
df.drop_duplicates(subset=['ap_paterno', 'ap_materno', 'nombre', 'email'], keep='last', inplace=True)
df.count()
# Out:
# clave_alu       805
# ap_paterno      805
# ap_materno      805
# nombre          805
# sexo            682
# ciudad          698
# email           634
# calificacion    805
# gpa             805
# fecha           805
# dtype: int64

# %%
df
# Out:
#      clave_alu ap_paterno ap_materno         nombre sexo  \
# 0     11030172   BORBOLLA      RAMOS        ARGELIA    F
# 1     11030173     CASTRO    MANCERA  KARLA MARIANA    F
# 2     11030177   FERRUSCA    ANDRADE        OCTAVIO    M
# 3     11030178     GARCIA      GOMEZ         RAFAEL    M
# 4     11030180  GUTIERREZ     FLORES   CARLOS DAVID    M
# ..         ...        ...        ...            ...  ...
# 800   11080209    MORALES    CARMONA  KARLA MARIANA    F
# 801   11080210   GUERRERO  COLOMBRES    ALDO ENRICO    M
# 802  120800002    Mendoza          G           Omar  NaN
# 803   12080001                                       NaN
# 807   14080004      MEJIA    JIMENEZ          LUISA  NaN
#
#                     ciudad                        email  calificacion  gpa  \
# 0                QUERETARO         argi_gogos@email.com           5.0  1.5
# 1    SANTIAGO DE QUERETARO                          NaN           5.0  1.5
# ...

# %%
df['sexo'].unique()
df.sexo.unique()
# Out:
# array(['F', 'M', nan], dtype=object)

# %%
df.ciudad.unique()
# Out:
# array(['QUERETARO', 'SANTIAGO DE QUERETARO', 'QUERETRO', nan,
#        'CORREGIDORA', 'QUERETARO QRO', 'EL PUEBLITO', 'QUER', 'MEXICO',
#        'CADEREYTA', 'SANTIAGO DE QUER', 'QUERETARO MEXICO',
#        'SANTIAGO QUERETARO', 'SANTIAGO DE QRO', 'QUERETAROQUERETARO',
#        'QUERETATO', 'QUERETARO QRO.', 'QUEREARO', 'QUERETAROQRO',
#        'QUERETARO ARTEAGA', 'QUERTERARO', 'PUEBLITO', 'QUERETARO  QRO.',
#        'QRO.', 'COLON', 'QUERETQRO', 'SANTIAGO DE QUERETARO QRO.',
#        'SANTIAGO DE QUERETARO QUERETARO', 'QUERE',
#        'SANTIAGO DE QUERETATARO', 'ACAMBARO', 'SAN LUIS DE LA PAZ',
#        'QUERETARO DE ARTEAGA', 'SGO. QUERETARO QRO.',
#        'SATIAGO DE QUERETARO', 'SANTIAGO DE QUERETAROQRO',
#        'CIUDAD DE MEXICO', 'PUEBLA', 'VILLA CORREGIDORA',
#        'SAN JOSE I GTO.', 'QUERATARO', 'SAN JOSE ITURBIDE', 'RIOVERE',
#        'SANTIAGO  DE  QUERETARO', 'IRPUATO'], dtype=object)

# %%
df.ciudad.value_counts()
# Out:
# QUERETARO                          532
# SANTIAGO DE QUERETARO               83
# QUERETARO QRO.                      13
# QUER                                 8
# CORREGIDORA                          7
# EL PUEBLITO                          5
# QUERETAROQRO                         5
# MEXICO                               4
# QUERETARO QRO                        3
# QUERETATO                            2
# PUEBLA                               2
# SAN JOSE ITURBIDE                    2
# SAN JOSE I GTO.                      1
# VILLA CORREGIDORA                    1
# QUERE                                1
# QUERATARO                            1
# CIUDAD DE MEXICO                     1
# RIOVERE                              1
# SANTIAGO DE QUERETAROQRO             1
# SATIAGO DE QUERETARO                 1
# SGO. QUERETARO QRO.                  1
# QUERETARO DE ARTEAGA                 1
# SANTIAGO  DE  QUERETARO              1
# SAN LUIS DE LA PAZ                   1
# ...

# %%
dic_queretaro={
    'SANTIAGO DE QUERETARO': 'QUERETARO',
    'QUERETARO QRO.': 'QUERETARO',
    'QUER':'QUERETARO',
    'QUERETAROQRO': 'QUERETARO'
}
df['ciudad']=df['ciudad'].replace(dic_queretaro)
df.ciudad.value_counts()
# Out:
# QUERETARO                          641
# CORREGIDORA                          7
# EL PUEBLITO                          5
# MEXICO                               4
# QUERETARO QRO                        3
# SAN JOSE ITURBIDE                    2
# QUERETATO                            2
# PUEBLA                               2
# SANTIAGO DE QUERETAROQRO             1
# ACAMBARO                             1
# SAN LUIS DE LA PAZ                   1
# QUERETARO DE ARTEAGA                 1
# SGO. QUERETARO QRO.                  1
# SATIAGO DE QUERETARO                 1
# VILLA CORREGIDORA                    1
# CIUDAD DE MEXICO                     1
# QUERE                                1
# SAN JOSE I GTO.                      1
# QUERATARO                            1
# RIOVERE                              1
# SANTIAGO  DE  QUERETARO              1
# SANTIAGO DE QUERETATARO              1
# QUERETQRO                            1
# SANTIAGO DE QUERETARO QUERETARO      1
# ...

# %%
#df.loc[:'ciudad'][pd.notnull(df['ciudad']) 
#  & ((df.ciudad.str.contains('QUER', na=False)) | df.ciudad.str.contains('QRO', na=False))]\
#     = 'QUERETARO'
#df.ciudad.value_counts()

# %%
df['ciudad']=df['ciudad'].replace(to_replace='[sS]AN', value ='NUEVO', regex =True)
df.ciudad.value_counts()
# Out:
# QUERETARO                            641
# CORREGIDORA                            7
# EL PUEBLITO                            5
# MEXICO                                 4
# QUERETARO QRO                          3
# NUEVO JOSE ITURBIDE                    2
# QUERETATO                              2
# PUEBLA                                 2
# NUEVOTIAGO DE QUERETAROQRO             1
# ACAMBARO                               1
# NUEVO LUIS DE LA PAZ                   1
# QUERETARO DE ARTEAGA                   1
# SGO. QUERETARO QRO.                    1
# SATIAGO DE QUERETARO                   1
# VILLA CORREGIDORA                      1
# CIUDAD DE MEXICO                       1
# QUERE                                  1
# NUEVO JOSE I GTO.                      1
# QUERATARO                              1
# RIOVERE                                1
# NUEVOTIAGO  DE  QUERETARO              1
# NUEVOTIAGO DE QUERETATARO              1
# QUERETQRO                              1
# ...

# %%
#df.drop(['ciudad, axis=1 , inplace =True])
df
# Out:
#      clave_alu ap_paterno ap_materno         nombre sexo     ciudad  \
# 0     11030172   BORBOLLA      RAMOS        ARGELIA    F  QUERETARO
# 1     11030173     CASTRO    MANCERA  KARLA MARIANA    F  QUERETARO
# 2     11030177   FERRUSCA    ANDRADE        OCTAVIO    M  QUERETARO
# 3     11030178     GARCIA      GOMEZ         RAFAEL    M  QUERETARO
# 4     11030180  GUTIERREZ     FLORES   CARLOS DAVID    M  QUERETARO
# ..         ...        ...        ...            ...  ...        ...
# 800   11080209    MORALES    CARMONA  KARLA MARIANA    F        NaN
# 801   11080210   GUERRERO  COLOMBRES    ALDO ENRICO    M  QUERETARO
# 802  120800002    Mendoza          G           Omar  NaN        NaN
# 803   12080001                                       NaN        NaN
# 807   14080004      MEJIA    JIMENEZ          LUISA  NaN        NaN
#
#                            email  calificacion  gpa      fecha
# 0           argi_gogos@email.com           5.0  1.5 2018-01-01
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 805 entries, 0 to 807
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   clave_alu     805 non-null    int64
#  1   ap_paterno    805 non-null    object
#  2   ap_materno    805 non-null    object
#  3   nombre        805 non-null    object
#  4   sexo          682 non-null    object
#  5   ciudad        698 non-null    object
#  6   email         634 non-null    object
#  7   calificacion  805 non-null    float64
#  8   gpa           805 non-null    float64
#  9   fecha         805 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), float64(2), int64(1), object(6)
# memory usage: 69.2+ KB

# %%
df=df.applymap(lambda x:x.capitalize() if isinstance(x,str) else x)
df
# Out:
#      clave_alu ap_paterno ap_materno         nombre sexo     ciudad  \
# 0     11030172   Borbolla      Ramos        Argelia    F  Queretaro
# 1     11030173     Castro    Mancera  Karla mariana    F  Queretaro
# 2     11030177   Ferrusca    Andrade        Octavio    M  Queretaro
# 3     11030178     Garcia      Gomez         Rafael    M  Queretaro
# 4     11030180  Gutierrez     Flores   Carlos david    M  Queretaro
# ..         ...        ...        ...            ...  ...        ...
# 800   11080209    Morales    Carmona  Karla mariana    F        NaN
# 801   11080210   Guerrero  Colombres    Aldo enrico    M  Queretaro
# 802  120800002    Mendoza          G           Omar  NaN        NaN
# 803   12080001                                       NaN        NaN
# 807   14080004      Mejia    Jimenez          Luisa  NaN        NaN
#
#                            email  calificacion  gpa      fecha
# 0           Argi_gogos@email.com           5.0  1.5 2018-01-01
# ...

# %%
aleatorio =['Limpio', 'Promedio', 'Inaceptable', 'Algo limpio', 'Algo sucio', 'Medio', 'Sucio']
naleatorio = np.random.randint(0,6, size=805)
naleatorio
# Out:
# array([2, 5, 2, 2, 2, 1, 0, 4, 1, 0, 1, 2, 1, 4, 1, 3, 3, 0, 1, 4, 3, 4,
#        3, 1, 5, 1, 3, 4, 3, 5, 2, 4, 3, 2, 3, 2, 1, 2, 5, 5, 1, 2, 0, 5,
#        2, 0, 4, 5, 1, 3, 0, 2, 4, 3, 0, 0, 0, 1, 0, 5, 0, 1, 2, 4, 5, 5,
#        5, 4, 2, 3, 5, 3, 2, 5, 0, 4, 3, 0, 0, 5, 0, 1, 3, 4, 0, 5, 3, 5,
#        3, 3, 4, 5, 2, 3, 4, 1, 1, 5, 1, 3, 0, 1, 4, 3, 0, 4, 0, 1, 0, 5,
#        2, 3, 0, 1, 0, 2, 5, 2, 4, 1, 5, 5, 5, 3, 5, 3, 0, 3, 3, 0, 3, 3,
#        2, 1, 3, 4, 3, 1, 2, 1, 0, 5, 2, 4, 2, 3, 2, 3, 5, 4, 2, 3, 3, 2,
#        1, 3, 5, 2, 5, 4, 4, 4, 1, 5, 0, 1, 5, 0, 1, 1, 4, 5, 3, 1, 2, 1,
#        3, 0, 4, 1, 2, 4, 4, 0, 2, 3, 2, 1, 4, 0, 2, 3, 2, 1, 2, 1, 4, 0,
#        5, 5, 3, 5, 3, 1, 1, 0, 1, 4, 1, 5, 0, 3, 2, 1, 0, 4, 0, 4, 5, 1,
#        3, 2, 1, 1, 1, 2, 2, 4, 0, 2, 4, 1, 0, 4, 2, 1, 3, 3, 3, 5, 1, 3,
#        2, 4, 0, 3, 3, 1, 4, 2, 1, 2, 2, 3, 5, 4, 2, 3, 0, 5, 4, 1, 4, 1,
#        2, 0, 3, 0, 1, 5, 3, 3, 3, 5, 0, 3, 1, 5, 1, 0, 4, 3, 5, 0, 4, 4,
# ...

# %%
limpieza =[]
for i in naleatorio:
    limpieza.append(aleatorio[i])

df['limpieza']= limpieza
df
# Out:
#      clave_alu ap_paterno ap_materno         nombre sexo     ciudad  \
# 0     11030172   Borbolla      Ramos        Argelia    F  Queretaro
# 1     11030173     Castro    Mancera  Karla mariana    F  Queretaro
# 2     11030177   Ferrusca    Andrade        Octavio    M  Queretaro
# 3     11030178     Garcia      Gomez         Rafael    M  Queretaro
# 4     11030180  Gutierrez     Flores   Carlos david    M  Queretaro
# ..         ...        ...        ...            ...  ...        ...
# 800   11080209    Morales    Carmona  Karla mariana    F        NaN
# 801   11080210   Guerrero  Colombres    Aldo enrico    M  Queretaro
# 802  120800002    Mendoza          G           Omar  NaN        NaN
# 803   12080001                                       NaN        NaN
# 807   14080004      Mejia    Jimenez          Luisa  NaN        NaN
#
#                            email  calificacion  gpa      fecha     limpieza
# ...

# %%
df.limpieza.value_counts()
# Out:
# Inaceptable    149
# Algo limpio    146
# Medio          144
# Promedio       140
# Limpio         114
# Algo sucio     112
# Name: limpieza, dtype: int64

# %%
df_cat = pd.read_csv('https://raw.githubusercontent.com/omarmendoza564/datos/main/datos/categorias.csv')
df_cat
# Out:
#       limpieza       seguridad        satisfaccion
# 0       Limpio         Neutral   Muy satisfactorio
# 1     Promedio      Muy seguro             Neutral
# 2  Algo limpio     Algo seguro     Algo satisfecho
# 3   Algo sucio    Muy inseguro   Algo insatisfecho
# 4        Sucio   Algo inseguro    Muy insatisfecho

# %%
cat_limpiar = set(df['limpieza']).difference(df_cat ['limpieza'])
cat_limpiar
# Out:
# {'Inaceptable', 'Medio'}

# %%
row_limpiar =df['limpieza'].isin(cat_limpiar)
df[row_limpiar]
# Out:
#      clave_alu ap_paterno ap_materno          nombre sexo     ciudad  \
# 0     11030172   Borbolla      Ramos         Argelia    F  Queretaro
# 1     11030173     Castro    Mancera   Karla mariana    F  Queretaro
# 2     11030177   Ferrusca    Andrade         Octavio    M  Queretaro
# 3     11030178     Garcia      Gomez          Rafael    M  Queretaro
# 4     11030180  Gutierrez     Flores    Carlos david    M  Queretaro
# ..         ...        ...        ...             ...  ...        ...
# 795   11080204   Aguillon   Resendiz            Jose    M  Queretaro
# 796   11080205      Baduy     Valdez   Kennia asenet    F  Queretaro
# 797   11080206       Nava     Torres  Leonardo jesus    M  Queretaro
# 799   11080208   Becerril     Huerta         Mariana    F  Queretaro
# 807   14080004      Mejia    Jimenez           Luisa  NaN        NaN
#
#                            email  calificacion  gpa      fecha     limpieza
# ...

# %%
df[~row_limpiar]
# Out:
#      clave_alu ap_paterno ap_materno          nombre sexo     ciudad  \
# 5     11030183    Jimenez   Carrillo  Ramon humberto  NaN  Queretaro
# 6     11030188   Martinez     Rivera    Javier josue    M   Queretro
# 7     11030199    Rosales     Apreza   Nestor martin    M  Queretaro
# 8     11030201     Suarez    Sanchez           Oscar    M  Queretaro
# 9     11030204    Vazquez   Gonzalez         Roberto    M  Queretaro
# ..         ...        ...        ...             ...  ...        ...
# 798   11080207      Lopez    Aguilar          Daniel    M    Irpuato
# 800   11080209    Morales    Carmona   Karla mariana    F        NaN
# 801   11080210   Guerrero  Colombres     Aldo enrico    M  Queretaro
# 802  120800002    Mendoza          G            Omar  NaN        NaN
# 803   12080001                                        NaN        NaN
#
#                                    email  calificacion  gpa      fecha  \
# ...

# %%
dic_limpiar = {'Inaceptable': 'Sucio', 'Medio': 'Algo limpio'}
df['limpieza']=df['limpieza'].replace (dic_limpiar)
set(df['limpieza']).difference(df_cat['limpieza'])
# Out:
# set()
