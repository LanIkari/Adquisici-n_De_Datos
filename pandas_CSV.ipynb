# %% [markdown]
# <a href="https://colab.research.google.com/github/LanIkari/Adquisicion_De_Datos/blob/main/pandas_CSV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Leer dataset 

import pandas as pd
#https://github.com/omarmendoza564/datos/blob/main/datos/casoscovid20201101.csv

# %%
#Data frame. Leeremos el documento con la libreria pandas 
df= pd.read_csv('https://raw.githubusercontent.com/omarmendoza564/datos/main/datos/casoscovid20201101.csv')
df.columns
# Out:
# Index(['ORIGEN', 'SEXO', 'ENTIDAD', 'FECHA_INGRESO', 'INTUBADO', 'NEUMONIA',
#        'EDAD', 'NACIONALIDAD', 'EMBARAZO', 'DIABETES', 'EPOC', 'ASMA',
#        'INMUSUPR', 'HIPERTENSION', 'CARDIOVASCULAR', 'OBESIDAD',
#        'RENAL_CRONICA', 'TABAQUISMO', 'RESULTADO_LAB', 'CLASIFICACION_FINAL'],
#       dtype='object')

# %%
df.

# %%
df.head()

# %%
df.describe()
# Out:
#            ORIGEN    INTUBADO    NEUMONIA        EDAD    EMBARAZO    DIABETES  \
# count  200.000000  200.000000  200.000000  200.000000  200.000000  200.000000
# mean     1.535000   74.665000   11.030000   42.555000   49.490000    2.355000
# std      0.500025   40.495087   28.575899   18.961929   47.659701    6.805184
# min      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
# 25%      1.000000   97.000000    2.000000   29.000000    2.000000    2.000000
# 50%      2.000000   97.000000    2.000000   41.000000   49.500000    2.000000
# 75%      2.000000   97.000000    2.000000   55.000000   97.000000    2.000000
# max      2.000000   99.000000   99.000000   86.000000   98.000000   98.000000
#
#              EPOC        ASMA    INMUSUPR  HIPERTENSION  CARDIOVASCULAR  \
# count  200.000000  200.000000  200.000000     200.00000      200.000000
# mean     2.455000    2.460000    2.460000       2.29500        2.465000
# ...

# %%
#Solo traera la informacion que corresponde al campo EDAD 
df.EDAD.describe()

# %%
#Nos dice cuantos renglones y cuantos elementos tenemos en df
df.shape
# Out:
# (200, 20)

# %%
df.EDAD
edad=df.EDAD 
edad.dypes 
edad[9]
edad[9:20]
# Out:
# 0      68
# 1      33
# 2      52
# 3      48
# 4      43
#        ..
# 195    27
# 196    28
# 197    30
# 198    53
# 199    41
# Name: EDAD, Length: 200, dtype: int64

# %%
df[9:20]
# Out:
#     ORIGEN    SEXO           ENTIDAD        FECHA_INGRESO  INTUBADO  NEUMONIA  \
# 9        2   MUJER   San Luis Potosí  2020-06-13 00:00:00        97         2
# 10       2  HOMBRE           Tabasco  2020-05-25 00:00:00        97         2
# 11       1   MUJER           Jalisco  2020-02-18 00:00:00        97        99
# 12       2   MUJER   Baja California  2020-05-25 00:00:00        97         2
# 13       2   MUJER  Estado de México  2020-05-20 00:00:00        97         2
# 14       1  HOMBRE         Querétaro  2020-02-18 00:00:00        97         2
# 15       1  HOMBRE           Jalisco  2020-02-10 00:00:00         2         1
# 16       2  HOMBRE          Veracruz  2020-03-27 00:00:00        97         2
# 17       2  HOMBRE           Sinaloa  2020-03-20 00:00:00        97         2
# 18       2  HOMBRE  Ciudad de México  2020-06-29 00:00:00        97         2
# 19       2  HOMBRE           Durango  2020-03-13 00:00:00        97         2
#
# ...

# %%
df.iloc[11]
# Out:
# ORIGEN                                   1
# SEXO                                 MUJER
# ENTIDAD                            Jalisco
# FECHA_INGRESO          2020-02-18 00:00:00
# INTUBADO                                97
# NEUMONIA                                99
# EDAD                                    13
# NACIONALIDAD                      MEXICANA
# EMBARAZO                                 2
# DIABETES                                 2
# EPOC                                     2
# ASMA                                     2
# INMUSUPR                                 2
# HIPERTENSION                             2
# CARDIOVASCULAR                           2
# OBESIDAD                                 2
# RENAL_CRONICA                            2
# TABAQUISMO                               2
# RESULTADO_LAB                           97
# CLASIFICACION_FINAL                      6
# Name: 11, dtype: object

# %%
#Visualizamos el parametro y varlo de una columna
df.iloc[9]
# Out:
# ORIGEN                                   2
# SEXO                                 MUJER
# ENTIDAD                    San Luis Potosí
# FECHA_INGRESO          2020-06-13 00:00:00
# INTUBADO                                97
# NEUMONIA                                 2
# EDAD                                    33
# NACIONALIDAD                      MEXICANA
# EMBARAZO                                 2
# DIABETES                                 2
# EPOC                                     2
# ASMA                                     2
# INMUSUPR                                 2
# HIPERTENSION                             2
# CARDIOVASCULAR                           2
# OBESIDAD                                 2
# RENAL_CRONICA                            2
# TABAQUISMO                               2
# RESULTADO_LAB                            1
# CLASIFICACION_FINAL                      3
# Name: 9, dtype: object

# %%
#Conjunto de renglones que deseo mostra. Comezamndo desde que empieza la clse. 
df.iloc[[1,6,8]]

# %%
#Ver las columnas 1 al 4 de todos los renglones del df
df.iloc[2, 1:5]
#Renglones colomnas
# Out:
# SEXO                           MUJER
# ENTIDAD                    Zacatecas
# FECHA_INGRESO    2020-01-05 00:00:00
# INTUBADO                           2
# Name: 2, dtype: object

# %%
#Ver las columnas 1 al 4 de los renglones 10 al 15 del df 
df.iloc[9:15, 1:5]
# Out:
#       SEXO           ENTIDAD        FECHA_INGRESO  INTUBADO
# 9    MUJER   San Luis Potosí  2020-06-13 00:00:00        97
# 10  HOMBRE           Tabasco  2020-05-25 00:00:00        97
# 11   MUJER           Jalisco  2020-02-18 00:00:00        97
# 12   MUJER   Baja California  2020-05-25 00:00:00        97
# 13   MUJER  Estado de México  2020-05-20 00:00:00        97
# 14  HOMBRE         Querétaro  2020-02-18 00:00:00        97

# %%
#Ver las columnas 1,2 y 7 de los renglones 10, 14 y 23 del df
df.iloc[[9,13, 22], [0,1,6]]
# Out:
#     ORIGEN    SEXO  EDAD
# 9        2   MUJER    33
# 13       2   MUJER    30
# 22       2  HOMBRE    49

# %%
#Ver las columnas de sexo a nacionalidad de todos los registros
df.loc[:,"SEXO": "NACIONALIDAD"]
# Out:
#        SEXO           ENTIDAD        FECHA_INGRESO  INTUBADO  NEUMONIA  EDAD  \
# 0     MUJER           Sinaloa  2020-06-11 00:00:00         2         1    68
# 1     MUJER  Ciudad de México  2020-05-23 00:00:00        97         2    33
# 2     MUJER         Zacatecas  2020-01-05 00:00:00         2         2    52
# 3    HOMBRE        Guanajuato  2020-06-24 00:00:00        97         2    48
# 4    HOMBRE  Ciudad de México  2020-06-08 00:00:00        97         2    43
# ..      ...               ...                  ...       ...       ...   ...
# 195  HOMBRE          Veracruz  2020-01-28 00:00:00        97        99    27
# 196   MUJER           Nayarit  2020-04-01 00:00:00        97         2    28
# 197  HOMBRE           Sinaloa  2020-05-02 00:00:00         2         1    30
# 198   MUJER          Veracruz  2020-03-25 00:00:00         2         2    53
# 199  HOMBRE           Sinaloa  2020-05-27 00:00:00        97         2    41
#
#     NACIONALIDAD
# 0       MEXICANA
# ...

# %%
#Ver las columnas de edad, sexo, y nacionalidad de los renglones 4,14,19 
df.loc[[4,14,19], ["EDAD","SEXO", "NACIONALIDAD"]]
# Out:
#     EDAD    SEXO NACIONALIDAD
# 4     43  HOMBRE     MEXICANA
# 14    59  HOMBRE     MEXICANA
# 19    65  HOMBRE     MEXICANA

# %%
#Ver las columnas de nacionalidad en adelante  de los renglones 5,15,20 
df.loc[[4,14,19], "NACIONALIDAD":]
# Out:
#    NACIONALIDAD  EMBARAZO  DIABETES  EPOC  ASMA  INMUSUPR  HIPERTENSION  \
# 4      MEXICANA        97         2     2     2         2             2
# 14     MEXICANA        97         2     2     2         2             1
# 19     MEXICANA        97         2     2     2         2             2
#
#     CARDIOVASCULAR  OBESIDAD  RENAL_CRONICA  TABAQUISMO  RESULTADO_LAB  \
# 4                2         2              2           2              1
# 14               2         1              2           2              2
# 19               2         2              2           2             97
#
#     CLASIFICACION_FINAL
# 4                     3
# 14                    7
# 19                    6

# %%
#Ver las columnas de edad, sexo, y nacionalidad de los renglones 4,14,19 
df.loc[[4,14,19], ["EDAD","SEXO", "NACIONALIDAD"]]
# Out:
#     EDAD    SEXO NACIONALIDAD
# 4     43  HOMBRE     MEXICANA
# 14    59  HOMBRE     MEXICANA
# 19    65  HOMBRE     MEXICANA

# %%
#Ver las columnas de edad, sexo, y nacionalidad de los renglones 4,14,19 
df.loc[[4,14,19], "NACIONALIDAD": "ASMA"]
# Out:
#    NACIONALIDAD  EMBARAZO  DIABETES  EPOC  ASMA
# 4      MEXICANA        97         2     2     2
# 14     MEXICANA        97         2     2     2
# 19     MEXICANA        97         2     2     2

# %%
#Filtrado 
df[(df['SEXO']=='MUJER')]
# Out:
#      ORIGEN   SEXO           ENTIDAD        FECHA_INGRESO  INTUBADO  NEUMONIA  \
# 0         1  MUJER           Sinaloa  2020-06-11 00:00:00         2         1
# 1         1  MUJER  Ciudad de México  2020-05-23 00:00:00        97         2
# 2         2  MUJER         Zacatecas  2020-01-05 00:00:00         2         2
# 5         1  MUJER           Jalisco  2020-04-03 00:00:00        97         2
# 6         1  MUJER  Ciudad de México  2020-07-02 00:00:00        97         2
# ..      ...    ...               ...                  ...       ...       ...
# 186       2  MUJER           Yucatán  2020-03-31 00:00:00        97         2
# 187       1  MUJER        Guanajuato  2020-02-26 00:00:00        97        99
# 188       2  MUJER        Nuevo León  2020-03-27 00:00:00        97         2
# 196       1  MUJER           Nayarit  2020-04-01 00:00:00        97         2
# 198       1  MUJER          Veracruz  2020-03-25 00:00:00         2         2
#
# ...

# %%
#Filtrado 
#Nos traemos iun rango de elemntos pero solo los que estan dentro de la igualdad
df[(df['SEXO']=='MUJER')]
df['SEXO']=='MUJER'
# Out:
# 0       True
# 1       True
# 2       True
# 3      False
# 4      False
#        ...
# 195    False
# 196     True
# 197    False
# 198     True
# 199    False
# Name: SEXO, Length: 200, dtype: bool

# %%
#Filtrado
df [(df['SEXO']=='MUJER')]
dfm =(df['SEXO']=='MUJER')
dfm
# Out:
# 0       True
# 1       True
# 2       True
# 3      False
# 4      False
#        ...
# 195    False
# 196     True
# 197    False
# 198     True
# 199    False
# Name: SEXO, Length: 200, dtype: bool

# %%
df[dfm].count()
# Out:
# ORIGEN                 103
# SEXO                   103
# ENTIDAD                103
# FECHA_INGRESO          103
# INTUBADO               103
# NEUMONIA               103
# EDAD                   103
# NACIONALIDAD           103
# EMBARAZO               103
# DIABETES               103
# EPOC                   103
# ASMA                   103
# INMUSUPR               103
# HIPERTENSION           103
# CARDIOVASCULAR         103
# OBESIDAD               103
# RENAL_CRONICA          103
# TABAQUISMO             103
# RESULTADO_LAB          103
# CLASIFICACION_FINAL    103
# dtype: int64

# %%
df[(df['SEXO']=='MUJER')&(df['EDAD']>=60)]
# Out:
#      ORIGEN   SEXO           ENTIDAD        FECHA_INGRESO  INTUBADO  NEUMONIA  \
# 0         1  MUJER           Sinaloa  2020-06-11 00:00:00         2         1
# 5         1  MUJER           Jalisco  2020-04-03 00:00:00        97         2
# 6         1  MUJER  Ciudad de México  2020-07-02 00:00:00        97         2
# 20        1  MUJER         Michoacán  2020-03-30 00:00:00         2         2
# 36        1  MUJER          Veracruz  2020-03-17 00:00:00        97         2
# 40        2  MUJER           Chiapas  2020-05-29 00:00:00        97         2
# 59        2  MUJER        Tamaulipas  2020-05-13 00:00:00        97         2
# 60        1  MUJER          Guerrero  2020-06-08 00:00:00         1         1
# 63        2  MUJER   San Luis Potosí  2020-03-31 00:00:00        97         2
# 76        1  MUJER           Chiapas  2020-05-15 00:00:00         2         2
# 80        1  MUJER          Veracruz  2020-01-17 00:00:00        97        99
# ...

# %%
df[(df['SEXO']=='MUJER')&(df['EDAD']>=60)] [['EDAD','ENTIDAD']]
# Out:
#      EDAD           ENTIDAD
# 0      68           Sinaloa
# 5      61           Jalisco
# 6      60  Ciudad de México
# 20     71         Michoacán
# 36     61          Veracruz
# 40     64           Chiapas
# 59     84        Tamaulipas
# 60     81          Guerrero
# 63     85   San Luis Potosí
# 76     75           Chiapas
# 80     85          Veracruz
# 89     63  Estado de México
# 102    77         Chihuahua
# 108    64           Chiapas
# 113    80          Coahuila
# 130    68           Jalisco
# 141    80          Veracruz
# 149    76          Guerrero
# 151    66           Sinaloa
# 177    86        Guanajuato
# 181    82  Ciudad de México

# %%
#Tenemos varias opciones para poder trabajar con, null, vacio, o Na
df[(df.ENTIDAD.isin(['Jalisco','Guerrero']))]
# Out:
#      ORIGEN    SEXO   ENTIDAD        FECHA_INGRESO  INTUBADO  NEUMONIA  EDAD  \
# 5         1   MUJER   Jalisco  2020-04-03 00:00:00        97         2    61
# 11        1   MUJER   Jalisco  2020-02-18 00:00:00        97        99    13
# 15        1  HOMBRE   Jalisco  2020-02-10 00:00:00         2         1    58
# 32        2  HOMBRE   Jalisco  2020-03-30 00:00:00        97         2    28
# 50        1  HOMBRE  Guerrero  2020-07-02 00:00:00        97         2    52
# 60        1   MUJER  Guerrero  2020-06-08 00:00:00         1         1    81
# 65        1   MUJER  Guerrero  2020-03-31 00:00:00        97         2    39
# 68        1  HOMBRE  Guerrero  2020-04-30 00:00:00         2         1    67
# 72        1  HOMBRE  Guerrero  2020-05-19 00:00:00         2         1    55
# 104       2   MUJER  Guerrero  2020-05-18 00:00:00        97         2    28
# 122       1  HOMBRE  Guerrero  2020-03-19 00:00:00        97         2    40
# ...

# %%
df[(df.ENTIDAD.isin(['Jalisco','Guerrero']))].count()
# Out:
# ORIGEN                 16
# SEXO                   16
# ENTIDAD                16
# FECHA_INGRESO          16
# INTUBADO               16
# NEUMONIA               16
# EDAD                   16
# NACIONALIDAD           16
# EMBARAZO               16
# DIABETES               16
# EPOC                   16
# ASMA                   16
# INMUSUPR               16
# HIPERTENSION           16
# CARDIOVASCULAR         16
# OBESIDAD               16
# RENAL_CRONICA          16
# TABAQUISMO             16
# RESULTADO_LAB          16
# CLASIFICACION_FINAL    16
# dtype: int64

# %%
df.isna()
# Out:
#      ORIGEN   SEXO  ENTIDAD  FECHA_INGRESO  INTUBADO  NEUMONIA   EDAD  \
# 0     False  False    False          False     False     False  False
# 1     False  False    False          False     False     False  False
# 2     False  False    False          False     False     False  False
# 3     False  False    False          False     False     False  False
# 4     False  False    False          False     False     False  False
# ..      ...    ...      ...            ...       ...       ...    ...
# 195   False  False    False          False     False     False  False
# 196   False  False    False          False     False     False  False
# 197   False  False    False          False     False     False  False
# 198   False  False    False          False     False     False  False
# 199   False  False    False          False     False     False  False
#
#      NACIONALIDAD  EMBARAZO  DIABETES   EPOC   ASMA  INMUSUPR  HIPERTENSION  \
# ...

# %%
df.EDAD.isna()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 195    False
# 196    False
# 197    False
# 198    False
# 199    False
# Name: EDAD, Length: 200, dtype: bool

# %%
df[df.ENTIDAD.str.contains('México')]
# Out:
#      ORIGEN    SEXO           ENTIDAD        FECHA_INGRESO  INTUBADO  \
# 1         1   MUJER  Ciudad de México  2020-05-23 00:00:00        97
# 4         2  HOMBRE  Ciudad de México  2020-06-08 00:00:00        97
# 6         1   MUJER  Ciudad de México  2020-07-02 00:00:00        97
# 7         1   MUJER  Ciudad de México  2020-03-05 00:00:00        97
# 8         2  HOMBRE  Ciudad de México  2020-05-26 00:00:00        97
# 13        2   MUJER  Estado de México  2020-05-20 00:00:00        97
# 18        2  HOMBRE  Ciudad de México  2020-06-29 00:00:00        97
# 24        2   MUJER  Ciudad de México  2020-05-14 00:00:00        97
# 25        2  HOMBRE  Ciudad de México  2020-04-15 00:00:00        97
# 26        2   MUJER  Estado de México  2020-04-01 00:00:00        97
# 29        2   MUJER  Estado de México  2020-05-16 00:00:00        97
# 33        1   MUJER  Ciudad de México  2020-05-21 00:00:00        97
# 34        1  HOMBRE  Ciudad de México  2020-05-05 00:00:00         2
# ...

# %%
#oRDENAR DE FORMA DESENDENTE!
df.sort_values(['ENTIDAD', 'EDAD'])
# Out:
#      ORIGEN    SEXO          ENTIDAD        FECHA_INGRESO  INTUBADO  NEUMONIA  \
# 139       2  HOMBRE   Aguascalientes  2020-03-18 00:00:00        97         2
# 79        1  HOMBRE   Aguascalientes  2020-01-17 00:00:00        97        99
# 90        1   MUJER   Aguascalientes  2020-03-17 00:00:00        97         2
# 128       1  HOMBRE   Aguascalientes  2020-01-22 00:00:00        97        99
# 144       2  HOMBRE  Baja California  2020-03-27 00:00:00        97         2
# ..      ...     ...              ...                  ...       ...       ...
# 111       1   MUJER          Yucatán  2020-06-29 00:00:00        97         2
# 131       1  HOMBRE        Zacatecas  2020-02-15 00:00:00        99        99
# 157       2   MUJER        Zacatecas  2020-03-25 00:00:00        97         2
# 2         2   MUJER        Zacatecas  2020-01-05 00:00:00         2         2
# 39        2  HOMBRE        Zacatecas  2020-05-08 00:00:00         2         1
#
# ...

# %%
df.sort_values('EDAD' , ascending=False)
# Out:
#      ORIGEN    SEXO          ENTIDAD        FECHA_INGRESO  INTUBADO  NEUMONIA  \
# 177       1   MUJER       Guanajuato  2020-05-27 00:00:00        97         2
# 63        2   MUJER  San Luis Potosí  2020-03-31 00:00:00        97         2
# 183       2  HOMBRE         Tlaxcala  2020-04-01 00:00:00         1         1
# 80        1   MUJER         Veracruz  2020-01-17 00:00:00        97        99
# 59        2   MUJER       Tamaulipas  2020-05-13 00:00:00        97         2
# ..      ...     ...              ...                  ...       ...       ...
# 139       2  HOMBRE   Aguascalientes  2020-03-18 00:00:00        97         2
# 125       2  HOMBRE       Nuevo León  2020-02-26 00:00:00        97         2
# 155       1   MUJER          Tabasco  2020-01-06 00:00:00        99        99
# 165       1   MUJER         Coahuila  2020-02-19 00:00:00        99        99
# 144       2  HOMBRE  Baja California  2020-03-27 00:00:00        97         2
#
# ...

# %%
df.groupby('SEXO').groups
# Out:
# {'HOMBRE': [3, 4, 8, 10, 14, 15, 16, 17, 18, 19, 21, 22, 25, 28, 30, 32, 34, 37, 38, 39, 41, 44, 46, 50, 51, 53, 55, 66, 67, 68, 69, 72, 74, 75, 79, 81, 82, 83, 85, 86, 88, 93, 94, 95, 100, 101, 103, 105, 107, 110, 117, 119, 120, 122, 123, 124, 125, 126, 128, 129, 131, 132, 133, 134, 135, 137, 139, 142, 143, 144, 145, 146, 148, 159, 160, 161, 162, 164, 166, 168, 169, 170, 172, 173, 175, 176, 183, 185, 189, 190, 191, 192, 193, 194, 195, 197, 199], 'MUJER': [0, 1, 2, 5, 6, 7, 9, 11, 12, 13, 20, 23, 24, 26, 27, 29, 31, 33, 35, 36, 40, 42, 43, 45, 47, 48, 49, 52, 54, 56, 57, 58, 59, 60, 61, 62, 63, 64, 65, 70, 71, 73, 76, 77, 78, 80, 84, 87, 89, 90, 91, 92, 96, 97, 98, 99, 102, 104, 106, 108, 109, 111, 112, 113, 114, 115, 116, 118, 121, 127, 130, 136, 138, 140, 141, 147, 149, 150, 151, 152, 153, 154, 155, 156, 157, 158, 163, 165, 167, 171, 174, 177, 178, 179, 180, 181, 182, 184, 186, 187, ...]}

# %%
df.groupby(['SEXO','EDAD']).groups
# Out:
# {('HOMBRE', 1): [144], ('HOMBRE', 4): [125], ('HOMBRE', 5): [51, 139, 164], ('HOMBRE', 8): [95, 131], ('HOMBRE', 10): [135], ('HOMBRE', 11): [175], ('HOMBRE', 13): [161], ('HOMBRE', 19): [105], ('HOMBRE', 21): [194], ('HOMBRE', 22): [46, 79, 103, 193], ('HOMBRE', 23): [162], ('HOMBRE', 24): [190], ('HOMBRE', 26): [83], ('HOMBRE', 27): [119, 160, 195], ('HOMBRE', 28): [16, 32], ('HOMBRE', 29): [41, 53, 82], ('HOMBRE', 30): [55, 100, 142, 197], ('HOMBRE', 31): [74, 110, 159], ('HOMBRE', 32): [75, 169], ('HOMBRE', 33): [132], ('HOMBRE', 34): [120], ('HOMBRE', 35): [69, 101], ('HOMBRE', 36): [86], ('HOMBRE', 37): [143], ('HOMBRE', 39): [148], ('HOMBRE', 40): [122], ('HOMBRE', 41): [124, 192, 199], ('HOMBRE', 42): [44, 168], ('HOMBRE', 43): [4], ('HOMBRE', 45): [8, 10, 67, 94, 176], ('HOMBRE', 46): [30, 185], ('HOMBRE', 47): [34], ('HOMBRE', 48): [3, 117, 134], ('HOMBRE', 49): [22], ('HOMBRE', 50): [21, 88, 107], ('HOMBRE', 51): [85], ('HOMBRE', 52): [50, 146, 189], ('HOMBRE', 53): [133],
# ...

# %%
df.groupby(['ENTIDAD','SEXO', 'EDAD']).groups
# Out:
# {('Aguascalientes', 'HOMBRE', 5): [139], ('Aguascalientes', 'HOMBRE', 22): [79], ('Aguascalientes', 'HOMBRE', 55): [128], ('Aguascalientes', 'MUJER', 30): [90], ('Baja California', 'HOMBRE', 1): [144], ('Baja California', 'HOMBRE', 61): [126], ('Baja California', 'MUJER', 34): [178], ('Baja California', 'MUJER', 42): [12], ('Baja California', 'MUJER', 44): [138], ('Campeche', 'HOMBRE', 49): [22], ('Chiapas', 'MUJER', 64): [40, 108], ('Chiapas', 'MUJER', 75): [76], ('Chihuahua', 'HOMBRE', 50): [21], ('Chihuahua', 'MUJER', 77): [102], ('Ciudad de México', 'HOMBRE', 22): [46], ('Ciudad de México', 'HOMBRE', 27): [119], ('Ciudad de México', 'HOMBRE', 29): [53], ('Ciudad de México', 'HOMBRE', 37): [143], ('Ciudad de México', 'HOMBRE', 41): [192], ('Ciudad de México', 'HOMBRE', 42): [44], ('Ciudad de México', 'HOMBRE', 43): [4], ('Ciudad de México', 'HOMBRE', 45): [8, 67, 176], ('Ciudad de México', 'HOMBRE', 46): [185], ('Ciudad de México', 'HOMBRE', 47): [34], ('Ciudad de México', 'HOMBRE
# ...

# %%
df.groupby('SEXO').get_group('MUJER')
# Out:
#      ORIGEN   SEXO           ENTIDAD        FECHA_INGRESO  INTUBADO  NEUMONIA  \
# 0         1  MUJER           Sinaloa  2020-06-11 00:00:00         2         1
# 1         1  MUJER  Ciudad de México  2020-05-23 00:00:00        97         2
# 2         2  MUJER         Zacatecas  2020-01-05 00:00:00         2         2
# 5         1  MUJER           Jalisco  2020-04-03 00:00:00        97         2
# 6         1  MUJER  Ciudad de México  2020-07-02 00:00:00        97         2
# ..      ...    ...               ...                  ...       ...       ...
# 186       2  MUJER           Yucatán  2020-03-31 00:00:00        97         2
# 187       1  MUJER        Guanajuato  2020-02-26 00:00:00        97        99
# 188       2  MUJER        Nuevo León  2020-03-27 00:00:00        97         2
# 196       1  MUJER           Nayarit  2020-04-01 00:00:00        97         2
# 198       1  MUJER          Veracruz  2020-03-25 00:00:00         2         2
#
# ...

# %%
df.groupby(['ENTIDAD', 'SEXO']).get_group(('Michoacán','MUJER'))
# Out:
#      ORIGEN   SEXO    ENTIDAD        FECHA_INGRESO  INTUBADO  NEUMONIA  EDAD  \
# 20        1  MUJER  Michoacán  2020-03-30 00:00:00         2         2    71
# 171       2  MUJER  Michoacán  2020-06-27 00:00:00        97         2    50
# 174       1  MUJER  Michoacán  2020-01-24 00:00:00        97        99    22
#
#     NACIONALIDAD  EMBARAZO  DIABETES  EPOC  ASMA  INMUSUPR  HIPERTENSION  \
# 20      MEXICANA         2         1     1     2         2             1
# 171     MEXICANA         2         2     2     2         2             2
# 174     MEXICANA        98         2     2     2         2             2
#
#      CARDIOVASCULAR  OBESIDAD  RENAL_CRONICA  TABAQUISMO  RESULTADO_LAB  \
# 20                2         1              2           1              2
# 171               2         2              2           2              1
# 174               2         2              2           2             97
#
#      CLASIFICACION_FINAL
# 20                     7
# ...

# %%
df.groupby('SEXO').count()
# Out:
#         ORIGEN  ENTIDAD  FECHA_INGRESO  INTUBADO  NEUMONIA  EDAD  \
# SEXO
# HOMBRE      97       97             97        97        97    97
# MUJER      103      103            103       103       103   103
#
#         NACIONALIDAD  EMBARAZO  DIABETES  EPOC  ASMA  INMUSUPR  HIPERTENSION  \
# SEXO
# HOMBRE            97        97        97    97    97        97            97
# MUJER            103       103       103   103   103       103           103
#
#         CARDIOVASCULAR  OBESIDAD  RENAL_CRONICA  TABAQUISMO  RESULTADO_LAB  \
# SEXO
# HOMBRE              97        97             97          97             97
# MUJER              103       103            103         103            103
#
#         CLASIFICACION_FINAL
# SEXO
# HOMBRE                   97
# MUJER                   103

# %%
df.groupby(['ENTIDAD', 'SEXO']).EDAD.count()
# Out:
# ENTIDAD           SEXO
# Aguascalientes    HOMBRE     3
#                   MUJER      1
# Baja California   HOMBRE     2
#                   MUJER      3
# Campeche          HOMBRE     1
# Chiapas           MUJER      3
# Chihuahua         HOMBRE     1
#                   MUJER      1
# Ciudad de México  HOMBRE    19
#                   MUJER     20
# Coahuila          MUJER      3
# Colima            HOMBRE     1
#                   MUJER      2
# Durango           HOMBRE     1
# Estado de México  HOMBRE     5
#                   MUJER      8
# Guanajuato        HOMBRE     8
#                   MUJER      8
# Guerrero          HOMBRE     4
#                   MUJER      4
# Hidalgo           HOMBRE     1
#                   MUJER      1
# Jalisco           HOMBRE     4
#                   MUJER      4
# Michoacán         MUJER      3
# Morelos           HOMBRE     1
# Nayarit           HOMBRE     2
#                   MUJER      1
# Nuevo León        HOMBRE     4
# ...

# %%
df.groupby(['ENTIDAD','SEXO']).EDAD.mean()
# Out:
# ENTIDAD           SEXO
# Aguascalientes    HOMBRE    27.333333
#                   MUJER     30.000000
# Baja California   HOMBRE    31.000000
#                   MUJER     40.000000
# Campeche          HOMBRE    49.000000
# Chiapas           MUJER     67.666667
# Chihuahua         HOMBRE    50.000000
#                   MUJER     77.000000
# Ciudad de México  HOMBRE    46.421053
#                   MUJER     45.000000
# Coahuila          MUJER     40.333333
# Colima            HOMBRE    34.000000
#                   MUJER     33.500000
# Durango           HOMBRE    65.000000
# Estado de México  HOMBRE    28.400000
#                   MUJER     39.000000
# Guanajuato        HOMBRE    28.625000
#                   MUJER     39.875000
# Guerrero          HOMBRE    53.500000
#                   MUJER     56.000000
# Hidalgo           HOMBRE    42.000000
#                   MUJER     46.000000
# Jalisco           HOMBRE    45.500000
#                   MUJER     48.250000
# ...

# %%
df['EDAD']*12
# Out:
# 0      816
# 1      396
# 2      624
# 3      576
# 4      516
#       ...
# 195    324
# 196    336
# 197    360
# 198    636
# 199    492
# Name: EDAD, Length: 200, dtype: int64

# %%
def meses (m):
  return m*12

df['EDAD'].apply(meses)
# Out:
# 0      816
# 1      396
# 2      624
# 3      576
# 4      516
#       ...
# 195    324
# 196    336
# 197    360
# 198    636
# 199    492
# Name: EDAD, Length: 200, dtype: int64

# %%
df['EDAD_,ESE']=df['EDAD'].apply(meses)
df.head()
# Out:
#    ORIGEN    SEXO           ENTIDAD        FECHA_INGRESO  INTUBADO  NEUMONIA  \
# 0       1   MUJER           Sinaloa  2020-06-11 00:00:00         2         1
# 1       1   MUJER  Ciudad de México  2020-05-23 00:00:00        97         2
# 2       2   MUJER         Zacatecas  2020-01-05 00:00:00         2         2
# 3       1  HOMBRE        Guanajuato  2020-06-24 00:00:00        97         2
# 4       2  HOMBRE  Ciudad de México  2020-06-08 00:00:00        97         2
#
#    EDAD NACIONALIDAD  EMBARAZO  DIABETES  ...  ASMA  INMUSUPR  HIPERTENSION  \
# 0    68     MEXICANA         2         1  ...     2         2             1
# 1    33     MEXICANA         2         2  ...     2         2             2
# 2    52     MEXICANA         2         2  ...     2         2             1
# 3    48     MEXICANA        97         2  ...     2         2             1
# 4    43     MEXICANA        97         2  ...     2         2             2
#
# ...

# %%
pd.unique(df.SEXO)
# Out:
# array(['MUJER', 'HOMBRE'], dtype=object)

# %%
pd.unique(df['EPOC'])
# Out:
# array([ 1,  2, 98])

# %%
pd.unique(df['ENTIDAD'])
# Out:
# array(['Sinaloa', 'Ciudad de México', 'Zacatecas', 'Guanajuato',
#        'Jalisco', 'San Luis Potosí', 'Tabasco', 'Baja California',
#        'Estado de México', 'Querétaro', 'Veracruz', 'Durango',
#        'Michoacán', 'Chihuahua', 'Campeche', 'Nuevo León', 'Chiapas',
#        'Quintana Roo', 'Puebla', 'Guerrero', 'Hidalgo', 'Tlaxcala',
#        'Tamaulipas', 'Coahuila', 'Nayarit', 'Sonora', 'Colima',
#        'Aguascalientes', 'Morelos', 'Oaxaca', 'Yucatán'], dtype=object)

# %%
print("MINIMO ", df['EDAD'].min())
print("MAXIMO ", df.EDAD.max())
print("PROMEDIO ", df['EDAD'].mean())
print("CONTEO ", df['EDAD'].count())
print("SUMA ", df['EDAD'].sum())
print("DESVIACION ", df['EDAD'].std())
# Out:
# MINIMO  1
# MAXIMO  86
# PROMEDIO  42.555
# CONTEO  200
# SUMA  8511
# DESVIACION  18.96192892993006
